# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Preparation

# %%
dataset = pd.read_csv(r'E:\pythonjupyter\datasets\car_data.csv')
dataset
# Out:
#      User ID  Gender  Age  AnnualSalary  Purchased
# 0        385    Male   35         20000          0
# 1        681    Male   40         43500          0
# 2        353    Male   49         74000          0
# 3        895    Male   40        107500          1
# 4        661    Male   25         79000          0
# ..       ...     ...  ...           ...        ...
# 995      863    Male   38         59000          0
# 996      800  Female   47         23500          0
# 997      407  Female   28        138500          1
# 998      299  Female   48        134000          1
# 999      687  Female   44         73500          0
#
# [1000 rows x 5 columns]

# %% [markdown]
# # EDA

# %%
print("Data Kosong:\n", dataset.isnull().sum())
print("\nData NaN:\n", dataset.isna().sum())
print("\nData Duplikat:\n", dataset.duplicated().sum())
print("\nTipe Data:\n", dataset.dtypes)
# Out:
# Data Kosong:
#  User ID         0
# Gender          0
# Age             0
# AnnualSalary    0
# Purchased       0
# dtype: int64
#
# Data NaN:
#  User ID         0
# Gender          0
# Age             0
# AnnualSalary    0
# Purchased       0
# dtype: int64
#
# Data Duplikat:
#  0
#
# Tipe Data:
#  User ID          int64
# Gender          object
# Age              int64
# AnnualSalary     int64
# Purchased        int64
# dtype: object

# %%
rows, columns = dataset.shape
print("\nVariabel (Kolom):", columns)
print("Baris:", rows)
# Out:
# Variabel (Kolom): 5
# Baris: 1000

# %%
dataset['Gender'] = dataset['Gender'].map({'Male': 0, 'Female': 1})

print("\nUnique Values in Gender Column:", dataset['Gender'].unique())
print("\nTipe Data Setelah Encoding:\n", dataset.dtypes)
print("\nData NaN Setelah Encoding:\n", dataset.isna().sum())
# Out:
# Unique Values in Gender Column: [0 1]
#
# Tipe Data Setelah Encoding:
#  User ID         int64
# Gender          int64
# Age             int64
# AnnualSalary    int64
# Purchased       int64
# dtype: object
#
# Data NaN Setelah Encoding:
#  User ID         0
# Gender          0
# Age             0
# AnnualSalary    0
# Purchased       0
# dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Gender', y='Age', data=dataset)
plt.title("Boxplot of Age by Gender")
plt.xlabel("Gender (0 = Male, 1 = Female)")
plt.ylabel("Age")
plt.show()

# %%
correlations = dataset.corr()
sns.heatmap(data=correlations, annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >
